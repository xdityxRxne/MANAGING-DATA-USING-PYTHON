# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in <module>
#      50 import pandas.core.config_init
#      51
# ---> 52 from pandas.core.api import (
#      53     # dtype
#      54     Int8Dtype,
#
# ~\anaconda3\lib\site-packages\pandas\core\api.py in <module>
#      27 from pandas.core.arrays.string_ import StringDtype
#      28 from pandas.core.construction import array
# ---> 29 from pandas.core.groupby import Grouper, NamedAgg
#      30 from pandas.core.indexes.api import (
#      31     CategoricalIndex,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\__init__.py in <module>
# ----> 1 from pandas.core.groupby.generic import DataFrameGroupBy, NamedAgg, SeriesGroupBy
#       2 from pandas.core.groupby.groupby import GroupBy
#       3 from pandas.core.groupby.grouper import Grouper
#       4
#       5 __all__ = [
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in <module>
#      64 import pandas.core.common as com
#      65 from pandas.core.construction import create_series_with_explicit_dtype
# ---> 66 from pandas.core.frame import DataFrame
#      67 from pandas.core.generic import ABCDataFrame, ABCSeries, NDFrame
#      68 from pandas.core.groupby import base
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in <module>
#     140     to_arrays,
#     141 )
# --> 142 from pandas.core.reshape.melt import melt
#     143 from pandas.core.series import Series
#     144 from pandas.core.sorting import ensure_key_mapped
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\melt.py in <module>
#      15 from pandas.core.indexes.api import Index, MultiIndex
#      16 from pandas.core.reshape.concat import concat
# ---> 17 from pandas.core.reshape.util import _tile_compat
#      18 from pandas.core.shared_docs import _shared_docs
#      19 from pandas.core.tools.numeric import to_numeric
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda3\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\anaconda3\lib\importlib\_bootstrap_external.py in get_code(self, fullname)
#
# ~\anaconda3\lib\importlib\_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %%
iris = pd.read_csv('iris.csv')

# %%
iris.mean()
# Out:
# Sepal.Length    5.843333
# Sepal.Width     3.057333
# Petal.Length    3.758000
# Petal.Width     1.199333
# dtype: float64

# %%
iris.median()
# Out:
# Sepal.Length    5.80
# Sepal.Width     3.00
# Petal.Length    4.35
# Petal.Width     1.30
# dtype: float64

# %%
iris.min()
# Out:
# Sepal.Length       4.3
# Sepal.Width          2
# Petal.Length         1
# Petal.Width        0.1
# Species         setosa
# dtype: object

# %%
iris.max()
# Out:
# Sepal.Length          7.9
# Sepal.Width           4.4
# Petal.Length          6.9
# Petal.Width           2.5
# Species         virginica
# dtype: object

# %%
def half(x):
    return (x*0.5)

# %%
iris[['Sepal.Length','Petal.Length']].apply(half)
# Out:
#      Sepal.Length  Petal.Length
# 0            2.55          0.70
# 1            2.45          0.70
# 2            2.35          0.65
# 3            2.30          0.75
# 4            2.50          0.70
# ..            ...           ...
# 145          3.35          2.60
# 146          3.15          2.50
# 147          3.25          2.60
# 148          3.10          2.70
# 149          2.95          2.55
#
# [150 rows x 2 columns]

# %%
iris['Species'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: Species, dtype: int64

# %%
iris.sort_values(by="Sepal.Length")
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]
